# %% [markdown]
# # Heading
#
# pkg(PyPlot)
# pkg(match)

# %%
include("OSteffAndCheck.jl")
#include("OPolyAndRealGenerator.jl")
include("OpolyAndReal.jl")
using PyPlot
using Match
setprecision(300)
# Out:
# WARNING: Method definition f1(Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:5 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:5.
# WARNING: Method definition f3(Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:6 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:6.
# WARNING: Method definition f4(Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:7 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:7.
# WARNING: Method definition f5(Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:8 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:8.
# WARNING: Method definition f6(Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:9 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:9.
# WARNING: Method definition newton(Any, Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:12 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:12.
# WARNING: Method definition steff(Any, Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:26 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:26.
# WARNING: Method definition check(Any, Any, Any, Any, Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:95 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:95.
# WARNING: Method definition check(Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:242 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:242.
# WARNING: Method definition dokladnosc(Any, Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:305 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:305.
# WARNING: Method definition rozbieganie(Any, Any, Any, Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:340 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:340.
# WARNING: Method definition poly_function(Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:4 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:4.
# WARNING: Method definition real_function(Any, Any) in module Main at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:115 overwritten at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:115.
# 300

# %% [markdown]
# funkcja Newtona: $x_{n+1}=x_n - \frac{f(x_n)}{f'(x_n)}\qquad k=0,1,...,$
# i funkcja Steffensena: $x_{k+1}:=x_k-\frac{f^2(x_k)}{f(x_k+f(x_k))-f(x_k)} \qquad k=0,1,...,$

# %% [markdown]
# $x-tan(x)$

# %%
n=150
x0=BigFloat(4.52)
nr=2
label="f(x)=x-tg(x)"
dokladnosc(n,nr,x0,label)

# %%
n=150
lebel="f(x)=x-tg(x)"
x0=BigFloat(7.7)
nr=2
dokladnosc(n,nr,x0,label)

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(4.5)
x1=BigFloat(7.7)
nr=2
rozbieganie(krok,nr,border,x,x1)

# %% [markdown]
# $f(x)=x^3-5x^2+3x-7$

# %%
n=15
label="f(x)=x^3-5x^2+3x-7"
x0=BigFloat(5.0)
nr=1
dokladnosc(n,nr,x0,label)

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
nr=1
x=BigFloat(5)
x1=BigFloat(5)
rozbieganie(krok,nr,border,x,x1)

# %% [markdown]
# dla $f(x)=x^2-2$
# i
# $f'(x)=2x$

# %%
n=10
label="f(x)=x^2 -2"
nr=100
dokladnosc(n,nr,x0,label)

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(-1.4)
x1=BigFloat(1.4)
nr=100
rozbieganie(krok,nr,border,x,x1)

# %% [markdown]
# $f(x)=2^x-10+5^{x/2}$
#
#
# $f'(x)=2^x \log(2)+\frac{1}{2} 5^{x/2} \log(5)$

# %%
n=10
label="2^x-10+5^(1/2*x)"
nr=3
x0=BigFloat(2)
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2bc373e890>)
# PyObject <matplotlib.legend.Legend object at 0x7f2bc352fe10>

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(2)
x1=BigFloat(2)
nr=3
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2bc350bdd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2bc3245f90>
