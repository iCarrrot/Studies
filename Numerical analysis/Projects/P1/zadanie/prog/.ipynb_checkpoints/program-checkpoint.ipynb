# %% [markdown]
# # Heading
#
# pkg(PyPlot)
# pkg(match)

# %%
include("program.jl")
#include("OPolyAndRealGenerator.jl")
include("funkcje.jl")
using PyPlot
using Match
setprecision(300)
# Out:
# 300

# %% [markdown]
# funkcja Newtona: $x_{n+1}=x_n - \frac{f(x_n)}{f'(x_n)}\qquad k=0,1,...,$
# i funkcja Steffensena: $x_{k+1}:=x_k-\frac{f^2(x_k)}{f(x_k+f(x_k))-f(x_k)} \qquad k=0,1,...,$

# %% [markdown]
# $x-tan(x)$

# %%
n=150
x0=BigFloat(4.5)
nr=2
label="f(x)=x-tg(x)"
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd3cb5a9750>)
# 4-element Array{Float64,1}:
#    0.0
#  165.0
#   -1.0
#  100.0

# %%
n=150
lebel="f(x)=x-tg(x)"
x0=BigFloat(7.7)
nr=2
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6eba7ba590>)
# PyObject <matplotlib.legend.Legend object at 0x7f6eba5f54d0>

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(4.5)
x1=BigFloat(7.7)
nr=2
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6ebad2c290>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f6eba7ba850>

# %% [markdown]
# $f(x)=x^3-5x^2+3x-7$

# %%
n=15
label="f(x)=x^3-5x^2+3x-7"
x0=BigFloat(5.0)
nr=1
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6ebac2ed10>)
# PyObject <matplotlib.legend.Legend object at 0x7f6ebaad5710>

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
nr=1
x=BigFloat(5)
x1=BigFloat(5)
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6ebafc4050>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f6ebad2c550>

# %% [markdown]
# dla $f(x)=x^2-2$
# i
# $f'(x)=2x$

# %%
n=10
label="f(x)=x^2 -2"
nr=100
x0=BigFloat(1.4)
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6ebb172e90>)
# PyObject <matplotlib.legend.Legend object at 0x7f6ebb019410>

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(-1.4)
x1=BigFloat(1.4)
nr=100
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6ebbf202d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f6ebb40b590>

# %% [markdown]
# $f(x)=2^x-10+5^{x/2}$
#
#
# $f'(x)=2^x \log(2)+\frac{1}{2} 5^{x/2} \log(5)$

# %%
n=10
label="2^x-10+5^(1/2*x)"
nr=3
x0=BigFloat(2)
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2bc373e890>)
# PyObject <matplotlib.legend.Legend object at 0x7f2bc352fe10>

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(2)
x1=BigFloat(2)
nr=3
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2bc350bdd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2bc3245f90>

# %% [markdown]
# $f(x)=-5x^5+ 3x^3+x+3$

# %%
n=10

label="f(x)=-5 x^5+3 x^3+x+3"
nr=72
x0=BigFloat(1.1)

dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd3cbabc9d0>)
# 4-element Array{Float64,1}:
#    0.0
#   11.0
#   -1.0
#  100.0

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(0.1)
x1=BigFloat(0.1)
nr=72
rozbieganie(krok,nr,border,x,x1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd3cf79d1d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fd3cbbf0510>

# %% [markdown]
# $f(x)=\cos{2^x}*\tan x$

# %%
n=100

label="cos(2^x)*tan(log10(x))"
#nr=72
#x0=BigFloat(1.1)
nr=60
x0=BigFloat(5)
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd3cb6a9910>)
# 4-element Array{Float64,1}:
#    0.0
#  110.0
#   -1.0
#  100.0

# %%
krok=BigFloat(0.1)
border=BigFloat(1000)
x=BigFloat(5)
x1=BigFloat(10)
nr=60
rozbieganie(krok,nr,border,x,x1)
# Out:
# LoadError: InterruptException:
# while loading In[29], in expression starting on line 6
#
#  in BigFloat() at ./mpfr.jl:71
#  in cos(::BigFloat) at ./mpfr.jl:636
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:381 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:65 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:64 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:63 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:62 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:61 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:60 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:59 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:58 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:57 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:56 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:55 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:54 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:53 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:52 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:51 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:50 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:49 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:48 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:47 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:46 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:45 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:44 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:43 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:42 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:41 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:40 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:39 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:38 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:37 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:36 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:35 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:34 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:33 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:32 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:31 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:30 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:29 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:28 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:27 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:26 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:25 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:24 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:23 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:22 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:21 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:20 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:19 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:18 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:17 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:16 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:15 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:14 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:13 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:12 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:11 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:10 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:9 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:8 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in macro expansion at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:7 [inlined]
#  in macro expansion at /home/michal/.julia/v0.6/Match/src/matchmacro.jl:0 [inlined]
#  in poly_function(::BigFloat, ::Int64) at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OpolyAndReal.jl:6
#  in steff(::BigFloat, ::#poly_function, ::Int64, ::Int64) at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:33
#  in check(::String, ::Function, ::Int64, ::BigFloat, ::BigFloat, ::BigFloat, ::BigFloat) at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:111
#  in rozbieganie(::BigFloat, ::Int64, ::BigFloat, ::BigFloat, ::BigFloat) at /home/michal/Dokumenty/Studies/ANM/Projects/P1/OSteffAndCheck.jl:365

# %%
n=100

label="cos(2^x)*tan(log10(x))"
#nr=72
#x0=BigFloat(1.1)
nr=88
x0=BigFloat(1.5)
dokladnosc(n,nr,x0,label)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd3cb9171d0>)
# 4-element Array{Float64,1}:
#    0.0
#  110.0
#   -1.0
#  100.0
